# %%
import cv2

# %%
img=cv2.imread(r"C:\Users\Akshay\Desktop\Semester 3\Deep Learning\Assignment\Assignment 1\Data\modified_data\face_1.jpg",1)

# %%
img.shape
# Out:
# (144, 192, 3)

# %%
cv2.imshow("face1",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resized_img=cv2.resize(img,(int(img.shape[1]/6),int(img.shape[0]/6)))

# %%
img=cv2.imread(r"C:\Users\Akshay\Desktop\Semester 3\Deep Learning\Assignment\Assignment 1\Data\modified_data\face_1.jpg",1)
resized_img=cv2.resize(img,(int(img.shape[1]/6),int(img.shape[0]/6)))
cv2.imshow("face1",resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resized_img.shape
# Out:
# (24, 32, 3)

# %%
int(img.shape[1])
# Out:
# 192

# %%
face_cascade=cv2.CascadeClassifier("haarcascade_frontalface_dafault.xml")

# %%
gray_image=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE
import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
tf.__version__
from PIL import Image
import glob

from sklearn.metrics import confusion_matrix,classification_report
from tensorflow.keras.models import Sequential, Model 
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Input
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Lambda, Input, AveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras.layers import BatchNormalization

# %%
raw_train = pd.read_csv(r"C:\Users\Akshay\Desktop\Semester 3\Deep Learning\Assignment\Assignment 1\Data\train_data.csv")

# %%
r_inx = np.random.choice(1000, 8)
rand_data = raw_train.loc[r_inx,'filename']

plt.figure(figsize=(30,4))
for i, image_path in enumerate(rand_data):
    im = np.asarray(Image.open(image_path))
    plt.subplot(1,8,i+1)
    plt.imshow(im,cmap='gray')
    plt.axis('off')
    
plt.show()

# %%
raw_train.shape
# Out:
# (2325, 5)

# %%
raw_train.head()
# Out:
#                            filename  person_id  series  tilt  pan
# 0   Data\modified_data\face_790.jpg          5       1   -15   30
# 1  Data\modified_data\face_2445.jpg          5       1     0  -75
# 2  Data\modified_data\face_2266.jpg          5       2   -15  -60
# 3  Data\modified_data\face_2713.jpg          5       2     0  -90
# 4  Data\modified_data\face_2016.jpg          5       2    15  -75

# %%
raw_train['filename']="Data\modified_data\\"+raw_train['filename']

# %%
raw_train['tilt'].value_counts()
# Out:
#  15    325
# -15    325
#  60    325
# -60    325
#  30    325
# -30    325
#  0     325
#  90     25
# -90     25
# Name: tilt, dtype: int64

# %%
pd.crosstab(raw_train['tilt'],raw_train['pan'])
# Out:
# pan   -90  -75  -60  -45  -30  -15   0    15   30   45   60   75   90
# tilt
# -90     0    0    0    0    0    0   25    0    0    0    0    0    0
# -60    25   25   25   25   25   25   25   25   25   25   25   25   25
# -30    25   25   25   25   25   25   25   25   25   25   25   25   25
# -15    25   25   25   25   25   25   25   25   25   25   25   25   25
#  0     25   25   25   25   25   25   25   25   25   25   25   25   25
#  15    25   25   25   25   25   25   25   25   25   25   25   25   25
#  30    25   25   25   25   25   25   25   25   25   25   25   25   25
#  60    25   25   25   25   25   25   25   25   25   25   25   25   25
#  90     0    0    0    0    0    0   25    0    0    0    0    0    0

# %%
raw_train.loc[raw_train['tilt']==60]
# Out:
#                               filename  person_id  series  tilt  pan
# 24    Data\modified_data\face_1603.jpg          5       2    60  -15
# 28     Data\modified_data\face_173.jpg          5       1    60   75
# 34    Data\modified_data\face_1813.jpg          5       1    60   60
# 35    Data\modified_data\face_2193.jpg          5       2    60   30
# 55     Data\modified_data\face_215.jpg          5       1    60   30
# ...                                ...        ...     ...   ...  ...
# 2274  Data\modified_data\face_1510.jpg         15       2    60    0
# 2285  Data\modified_data\face_1979.jpg         15       1    60   75
# 2287  Data\modified_data\face_2365.jpg         15       2    60  -15
# 2304  Data\modified_data\face_1395.jpg         15       1    60   60
# 2305   Data\modified_data\face_537.jpg         15       2    60   30
#
# [325 rows x 5 columns]

# %%
X=raw_train[['filename']]
tilt=raw_train[['tilt']]
pan=raw_train[['pan']]

# %%
split = train_test_split(raw_train, tilt, pan,
test_size=0.1, random_state=42,stratify=tilt)
(trainX, testX, trainTiltY, testTiltY,trainPanY, testPanY) = split

# %%
print(trainX.shape)
print(testX.shape)
print(trainTiltY.shape)
print(testTiltY.shape)
# Out:
# (2092, 5)
# (233, 5)
# (2092, 1)
# (233, 1)

# %%
split1 = train_test_split(trainX, trainTiltY, trainPanY,
test_size=0.2, random_state=42,stratify=trainTiltY)
(trainX1, valX1, trainTiltY1, valTiltY1,trainPanY1, valPanY1) = split1

# %%
print(trainX1.shape)
print(valX1.shape)
print(testX.shape)
# Out:
# (1673, 5)
# (419, 5)
# (233, 5)

# %%
testTiltY.tilt.value_counts()
# Out:
#  60    33
# -60    33
#  15    33
# -15    33
#  0     33
#  30    32
# -30    32
#  90     2
# -90     2
# Name: tilt, dtype: int64

# %%
train_df=pd.concat([trainX1,trainTiltY1,trainPanY1],axis=1)
val_df=pd.concat([valX1,valTiltY1,valPanY1],axis=1)
test_df=pd.concat([testX,testTiltY,testPanY],axis=1)

# %%
val_df.head()
# Out:
#                               filename  person_id  series  tilt  pan  tilt  \
# 1666   Data\modified_data\face_520.jpg         14       2    30  -75    30
# 832   Data\modified_data\face_1377.jpg         11       2     0  -60     0
# 1199  Data\modified_data\face_2294.jpg          6       1   -30    0   -30
# 1205  Data\modified_data\face_1362.jpg          6       1    30   90    30
# 1096  Data\modified_data\face_2400.jpg          6       1    60  -75    60
#
#       pan
# 1666  -75
# 832   -60
# 1199    0
# 1205   90
# 1096  -75

# %%
N_train_images = train_df.shape[0]
N_val_images = val_df.shape[0]
N_test_images=test_df.shape[0]

# %%
print("Training data shape:   ",train_df.shape)
print("Validation data shape: ",val_df.shape)
print("Testing data shape:    ",test_df.shape)
# Out:
# Training data shape:    (1673, 7)
# Validation data shape:  (419, 7)
# Testing data shape:     (233, 7)

# %%
train_df.head()
# Out:
#                               filename  person_id  series  tilt  pan  tilt  \
# 1180   Data\modified_data\face_666.jpg          6       2     0  -30     0
# 1771   Data\modified_data\face_771.jpg         13       2   -15   75   -15
# 330    Data\modified_data\face_816.jpg          4       1    60    0    60
# 1461  Data\modified_data\face_1743.jpg          9       2   -60    0   -60
# 305   Data\modified_data\face_1320.jpg          4       1    60   45    60
#
#       pan
# 1180  -30
# 1771   75
# 330     0
# 1461    0
# 305    45

# %%
train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
tst_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

# %%
batch_size = 32
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory='./',
    x_col="filename",
    y_col=["tilt","pan"],
    target_size=(24, 32),
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='raw')
# Out:
# Found 1673 validated image filenames.

# %%
batch_size = 32
validation_generator = val_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory='./',
    x_col="filename",
    y_col=["tilt","pan"],
    target_size=(24, 32),
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='raw')
# Out:
# Found 419 validated image filenames.

# %%
train_generator.labels
# Out:
# array([[  0,   0, -30, -30],
#        [-15, -15,  75,  75],
#        [ 60,  60,   0,   0],
#        ...,
#        [  0,   0,   0,   0],
#        [ 15,  15, -30, -30],
#        [ 60,  60, -75, -75]], dtype=int64)

# %%
def generate_data_generator(generator, X, Y1, Y2):
    genX = generator.flow(X, seed=7)
    genY1 = generator.flow(Y1, seed=7)
    while True:
            Xi = genX.next()
            Yi1 = genY1.next()
            Yi2 = function(Y2)
            yield Xi, [Yi1, Yi2]

# %%
input_ = Input(shape=(24, 32, 1))
x = Flatten()(input_)
#Hidden layer
h = Dense(64)(x)
h = Activation('relu')(h)
# Output layer
tilt_output = Dense(1, activation='linear', name='tilt_output')(x)
pan_output = Dense(1, activation='linear', name='pan_output')(x)

model_1 = Model(inputs=input_, outputs=[tilt_output,pan_output]) # Setup the model



model_1.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_7 (InputLayer)            [(None, 24, 32, 1)]  0
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 768)          0           input_7[0][0]
# __________________________________________________________________________________________________
# tilt_output (Dense)             (None, 1)            769         flatten_7[0][0]
# __________________________________________________________________________________________________
# pan_output (Dense)              (None, 1)            769         flatten_7[0][0]
# ...
# Total params: 1,538
# Trainable params: 1,538
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_1.compile(optimizer='adam', 
              loss={
                  'dense_10': 'mse', 
                  'dense_11': 'mse'},
              loss_weights={
                  'dense_10': 1, 
                  'dense_11': 1},
                  
              metrics={
                  'dense_10': 'mae', 
                  'dense_11': 'mae'})

# %%
hist=model_1.fit_generator(generator=train_generator,
                    validation_data=validation_generator,
                    epochs=2,verbose=1)
# Out:
# Epoch 1/2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-259-dd6f59df49b6> in <module>
#       1 hist=model_1.fit_generator(generator=train_generator,
#       2                     validation_data=validation_generator,
# ----> 3                     epochs=2,verbose=1)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1431         shuffle=shuffle,
#    1432         initial_epoch=initial_epoch,
# -> 1433         steps_name='steps_per_epoch')
#    1434
#    1435   def evaluate_generator(self,
#
# ...
